# %% [markdown]
# # Dataframe from file

# %%
import pandas as pd

# %%
students = pd.read_csv('..\\data\\students.csv', header=None)
students.head(1)

# %%
autos = pd.read_json('../data/autos.json')
autos.head()

# %%
scb = pd.read_excel('../data/be0101_tab8samdrag2022mar.xlsx', skiprows=3)
scb.head(3)
# Out:
#               Unnamed: 0      2022      2021      2020      2019      2018  \
# 0  Folkmängd 31 december  10521556  10452326  10379295  10327589  10230185
# 1                    Män   5298324   5260707   5222847   5195814   5142438
# 2                Kvinnor   5223232   5191619   5156448   5131775   5087747
#
#        2017     2016     2015     2014  ...       1986       1985       1984  \
# 0  10120242  9995153  9851017  9747355  ...  8381515.0  8358139.0  8342621.0
# 1   5082662  5013347  4930966  4872240  ...  4137513.0  4127110.0  4120549.0
# 2   5037580  4981806  4920051  4875115  ...  4244002.0  4231029.0  4222072.0
#
#         1983       1982       1981       1980       1975       1970       1960
# 0  8330573.0  8327484.0  8323033.0  8317937.0  8208442.0  8081229.0  7497967.0
# 1  4116137.0  4117357.0  4118622.0  4119822.0  4081263.0  4035911.0  3740119.0
# 2  4214436.0  4210127.0  4204411.0  4198115.0  4127179.0  4045318.0  3757848.0
#
# [3 rows x 47 columns]

# %%
scb.sample(3)
# Out:
#                                            Unnamed: 0    2022   2021   2020  \
# 41  2) Från och med 2011 är beräkningen gjord med ...     NaN    NaN    NaN
# 13                          Andelen utrikes födda i %    20.4     20   19.7
# 27                                     Invandringar    102436  90631  82518
#
#       2019    2018    2017    2016    2015    2014  ...         1986  \
# 41     NaN     NaN     NaN     NaN     NaN     NaN  ...          NaN
# 13    19.6    19.1    18.5    17.9      17    16.5  ...      7.99229
# 27  115805  132602  144489  163005  134240  126966  ...  39487.00000
#
#             1985         1984          1983          1982          1981  \
# 41           NaN          NaN           NaN           NaN           NaN
# 13      7.844438      7.73812      7.652067      7.626877      7.592785
# 27  33127.000000  31486.00000  27495.000000  30381.000000  32272.000000
#
#             1980          1975          1970          1960
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 6)
scb
# Out:
#                                            Unnamed: 0      2022      2021  \
# 0                               Folkmängd 31 december  10521556  10452326
# 1                                                 Män   5298324   5260707
# 2                                             Kvinnor   5223232   5191619
# ..                                                ...       ...       ...
# 54  10) Antal partners som avregistrerat partnersk...       NaN       NaN
# 55  11) Uppgifterna för åren 2000 till och med 201...       NaN       NaN
# 56        vilket innebär att en person räknats dub...       NaN       NaN
#
#         2020      2019      2018      2017     2016     2015     2014  \
# 0   10379295  10327589  10230185  10120242  9995153  9851017  9747355
# 1    5222847   5195814   5142438   5082662  5013347  4930966  4872240
# 2    5156448   5131775   5087747   5037580  4981806  4920051  4875115
# ..       ...       ...       ...       ...      ...      ...      ...
# ...

# %%
scb.shape
# Out:
# (57, 47)

# %%
len(scb)
len(scb.columns)
scb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 47 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  56 non-null     object
#  1   2022        38 non-null     object
#  2   2021        38 non-null     object
#  3   2020        38 non-null     object
#  4   2019        38 non-null     object
#  5   2018        38 non-null     object
#  6   2017        38 non-null     object
#  7   2016        38 non-null     object
#  8   2015        38 non-null     object
#  9   2014        38 non-null     object
#  10  2013        38 non-null     object
#  11  2012        38 non-null     object
#  12  2011        38 non-null     object
#  13  2010        36 non-null     object
#  14  2009        36 non-null     float64
#  15  2008        36 non-null     float64
#  16  2007        36 non-null     float64
#  17  2006        36 non-null     float64
#  18  2005        36 non-null     float64
# ...

# %%
scb.to_clipboard()

# %%
csv_string = scb.to_csv('../data/fil1.csv', index=None)

scb.to_json('../data/fil1.json', orient='columns')

# %%
scb.to_dict(orient='records')
0
# Out:
# 0
