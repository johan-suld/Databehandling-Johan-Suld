# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Series
# One dimensional array

# %%
fruits = pd.Series(['apple', 'pear', 'orange', 'melon', 'kiwi'], index=[5, 6, 'sju', 8, 9])
fruits
# Out:
# 5       apple
# 6        pear
# sju    orange
# 8       melon
# 9        kiwi
# dtype: object

# %%
fruits.apply(str.upper)
# Out:
# 0     APPLE
# 1      PEAR
# 2    ORANGE
# 3     MELON
# 4      KIWI
# dtype: object

# %%
numbers = pd.Series([5, 6, 3])

numbers[numbers >= 5]
# Out:
# 0    5
# 1    6
# dtype: int64

# %% [markdown]
# ### DataFrame
# Two dimensional data structure, consisting of series

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head(3)
#tips.tail()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', sizes=(20, 200), data=tips)

# %% [markdown]
# https://seaborn.pydata.org/tutorial.html
